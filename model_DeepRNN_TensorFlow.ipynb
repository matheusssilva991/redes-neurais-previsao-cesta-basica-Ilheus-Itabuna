# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import json
import configparser
from pathlib import Path
import os

from sklearn.metrics import mean_absolute_percentage_error as MAPE
from sklearn.metrics import mean_squared_error as MSE
def RMSE(y_real, y_predict):
    return np.sqrt(MSE(y_real, y_predict))

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN

configs = configparser.ConfigParser()
configs.read("configuracoes.conf",encoding='utf-8')
data_folder = Path(configs["DEFAULT"]["folder_path"])
path = data_folder / configs["DEFAULT"]["file"]
objeto = configs["DEFAULT"]["objeto"]
regiao = configs["DEFAULT"]["regiao"]

# %%
look_back = 12 #Quantidade de meses anteriores usado para prever
forecast_horizon = int(configs["DEFAULT"]["meses"]) #Quantidade de meses previstos

model_mape = []
model_rmse = []

for i in range(0,7):

    #Carrega os dados
    cesta = pd.read_excel(path)
    cesta.drop(['ano', 'salario', 'preco'], axis=1, inplace=True)

    #Cria sequencia de dados do tamanho (meses anterioes + meses a serem previstos)
    for n_step in range(1, look_back + forecast_horizon):
        cesta[f'razao t(h + {n_step})'] = cesta['razao'].shift(-n_step).values
    cesta.dropna(inplace=True)
    cesta.reset_index(drop=True, inplace=True)

    #Divide os dados em Treino e Teste
    X_train = cesta.iloc[:-67:, :look_back:].values
    y_train = cesta.iloc[:-67:, look_back::].values
    X_val = cesta.iloc[-67:-37:, :look_back:].values
    y_val = cesta.iloc[-67:-37:, look_back::].values
    y_val2 = cesta.iloc[-67:-37:, look_back::].values.tolist()

    #remodela os dados para formato (batchs, months, features)
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

    #Cria o modelo
    model=Sequential()
    model.add(SimpleRNN(32, input_shape=(look_back,1),return_sequences=True, stateful=True,batch_input_shape=(1, look_back, 1)))
    model.add(SimpleRNN(32, stateful=True))
    model.add(Dense(forecast_horizon))
    model.compile(loss='mean_squared_error', optimizer='adam')

    #Treina e pever (forecast_horizon) quantidade de tempo
    history = model.fit(X_train, y_train, epochs= 40, batch_size=1, shuffle=False, validation_data=(X_val, y_val))
    forecast = model.predict(X_val, batch_size=1)

    model_rmse.append(RMSE(y_val2, forecast))
    model_mape.append(MAPE(y_val2, forecast) * 100)

print(model_mape)

model_mape.sort()
model_rmse.sort()
model_mape.pop()
del model_mape[0]
model_rmse.pop()
del model_rmse[0]

mean_rmse = 0
mean_mape = 0

for rmse, mape in zip(model_rmse, model_mape):
    mean_rmse += rmse
    mean_mape += mape

mean_rmse = mean_rmse / 5
mean_mape = mean_mape / 5

"""
resultados = [valor for valor in forecast[0]]   
objeto = objeto.replace(" ",'_')
output = {objeto.lower():str(resultados)}
filename = f"previsao_DeepRNN_{objeto.lower()}_{regiao.lower()}_{forecast_horizon}_meses.json"
pasta_atual = os.getcwd()
full_url = Path(pasta_atual) / 'resultados' / 'previsoes' / filename
os.makedirs(os.path.dirname(full_url), exist_ok=True)
with open(full_url,"w") as file:
    json.dump(output,file,ensure_ascii=False)
print("Arquivo com resultados gerados")
"""
# Out:
# Epoch 1/40
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0115 - val_loss: 0.0011
# Epoch 2/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 3/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 4/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0058
# Epoch 5/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 6/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0105
# Epoch 7/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 8/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 9/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0010
# Epoch 10/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 11/40
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 12/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0045
# Epoch 13/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 14/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 15/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 16/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 17/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 18/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 19/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 9.5543e-04
# Epoch 20/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 8.9705e-04
# Epoch 21/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 22/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 23/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 9.8531e-04
# Epoch 24/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 8.2404e-04
# Epoch 25/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 7.4629e-04
# Epoch 26/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 7.5903e-04
# Epoch 27/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 7.5390e-04
# Epoch 28/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 7.7167e-04
# Epoch 29/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 8.1439e-04
# Epoch 30/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 8.2674e-04
# Epoch 31/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.0360e-04
# Epoch 32/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 33/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.8806e-04
# Epoch 34/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 35/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.3837e-04
# Epoch 36/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 7.7679e-04
# Epoch 37/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 9.1546e-04
# Epoch 38/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 6.3409e-04
# Epoch 39/40
# 120/120 [==============================] - 0s 3ms/step - loss: 9.5847e-04 - val_loss: 6.6439e-04
# Epoch 40/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 6.3074e-04
# Epoch 1/40
# 120/120 [==============================] - 2s 4ms/step - loss: 0.0150 - val_loss: 0.0011
# Epoch 2/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 9.0088e-04
# Epoch 3/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 4/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 5/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0047
# Epoch 6/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 7/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0074
# Epoch 8/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 9/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0189
# Epoch 10/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0087
# Epoch 11/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 12/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 13/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 14/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0138
# Epoch 15/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 16/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 17/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0187
# Epoch 18/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 19/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 20/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 21/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 22/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 23/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 24/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 9.0071e-04
# Epoch 25/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 9.4274e-04: 0s - loss: 0.00
# Epoch 26/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 27/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 28/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 9.3868e-04
# Epoch 29/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 30/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 8.7186e-04
# Epoch 31/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.7332e-04
# Epoch 32/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.2168e-04
# Epoch 33/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 8.0321e-04
# Epoch 34/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 8.8034e-04
# Epoch 35/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0125
# Epoch 36/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 8.1354e-04
# Epoch 37/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 9.3363e-04
# Epoch 38/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 7.4879e-04
# Epoch 39/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 8.0962e-04
# Epoch 40/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 6.8943e-04
# Epoch 1/40
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0139 - val_loss: 0.0039
# Epoch 2/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0095
# Epoch 3/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 4/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 5/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 6/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 7/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 8/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 9/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 10/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 11/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 12/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 13/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 14/40
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 15/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 16/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 6.4724e-04
# Epoch 17/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 6.4916e-04
# Epoch 18/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 6.4698e-04
# Epoch 19/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 6.8118e-04
# Epoch 20/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 6.7179e-04
# Epoch 21/40
# 120/120 [==============================] - 0s 3ms/step - loss: 9.7711e-04 - val_loss: 7.4738e-04
# Epoch 22/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 8.7106e-04
# Epoch 23/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 9.4476e-04
# Epoch 24/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0086
# Epoch 25/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 9.1017e-04
# Epoch 26/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.7116e-04
# Epoch 27/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.1822e-04
# Epoch 28/40
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 8.7663e-04
# Epoch 29/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 8.2219e-04
# Epoch 30/40
# 120/120 [==============================] - 0s 3ms/step - loss: 9.6952e-04 - val_loss: 7.6434e-04
# Epoch 31/40
# 120/120 [==============================] - 0s 3ms/step - loss: 9.5085e-04 - val_loss: 7.8679e-04
# Epoch 32/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 9.1357e-04
# Epoch 33/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 7.4245e-04
# Epoch 34/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 6.0755e-04
# Epoch 35/40
# 120/120 [==============================] - 0s 3ms/step - loss: 9.9193e-04 - val_loss: 5.8010e-04
# Epoch 36/40
# 120/120 [==============================] - 0s 3ms/step - loss: 9.6404e-04 - val_loss: 5.5820e-04
# Epoch 37/40
# 120/120 [==============================] - ETA: 0s - loss: 9.5667e-0 - 0s 3ms/step - loss: 9.3593e-04 - val_loss: 5.4539e-04
# Epoch 38/40
# 120/120 [==============================] - 0s 3ms/step - loss: 9.1416e-04 - val_loss: 5.3009e-04
# Epoch 39/40
# 120/120 [==============================] - 0s 3ms/step - loss: 8.9424e-04 - val_loss: 5.1547e-04
# Epoch 40/40
# 120/120 [==============================] - 0s 3ms/step - loss: 8.7793e-04 - val_loss: 5.0746e-04
# Epoch 1/40
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0404 - val_loss: 0.0023
# Epoch 2/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 3/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 4/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 5/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 6/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 7/40
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 8/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 9/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 10/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 11/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 12/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0159
# Epoch 13/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 14/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0114
# Epoch 15/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 9.4666e-04
# Epoch 16/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 17/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 18/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 9.5976e-04
# Epoch 19/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 20/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 21/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 22/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 23/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 9.5521e-04
# Epoch 24/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 9.4490e-04
# Epoch 25/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 9.5488e-04
# Epoch 26/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 9.8828e-04
# Epoch 27/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 9.9312e-04
# Epoch 28/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.7446e-04
# Epoch 29/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 9.2948e-04
# Epoch 30/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.1619e-04
# Epoch 31/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.7055e-04
# Epoch 32/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0125
# Epoch 33/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 9.0755e-04
# Epoch 34/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 35/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 9.3538e-04
# Epoch 36/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 8.8947e-04
# Epoch 37/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.0156e-04
# Epoch 38/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.7527e-04
# Epoch 39/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 6.5853e-04
# Epoch 40/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 7.2039e-04
# Epoch 1/40
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0137 - val_loss: 0.0012
# Epoch 2/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 9.4719e-04
# Epoch 3/40
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 4/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 5/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 6/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 7/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 8/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 9/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 10/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 11/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 12/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 13/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0129
# Epoch 14/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0455
# Epoch 15/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 8.3808e-04
# Epoch 16/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 9.2221e-04
# Epoch 17/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 18/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 19/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 9.2787e-04
# Epoch 20/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0052
# Epoch 21/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 22/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0155
# Epoch 23/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 24/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0107
# Epoch 25/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 26/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 27/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 28/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 29/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 30/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 31/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 32/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 33/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 34/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0066
# Epoch 35/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 36/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 37/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 38/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 39/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 9.0631e-04
# Epoch 40/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 1/40
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0144 - val_loss: 9.7445e-04
# Epoch 2/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 3/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0405
# Epoch 4/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 5.6684e-04
# Epoch 5/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 5.8194e-04
# Epoch 6/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 6.1964e-04
# Epoch 7/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 7.0125e-04
# Epoch 8/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 8.7427e-04
# Epoch 9/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 10/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 11/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 12/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0552
# Epoch 13/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0111
# Epoch 14/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 15/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0077
# Epoch 16/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 17/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 18/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0121
# Epoch 19/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 20/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 21/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 22/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 23/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 24/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 25/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 26/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 27/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 28/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0050
# Epoch 29/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 30/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 9.0498e-04
# Epoch 31/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 9.1519e-04
# Epoch 32/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 33/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 34/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 35/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 36/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 37/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 38/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 39/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 40/40
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 1/40
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0076 - val_loss: 0.0012
# Epoch 2/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 3/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 4/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 5/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 6/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 7/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 8/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 9/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 10/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 11/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 12/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 13/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 14/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 15/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 16/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 17/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 18/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 19/40
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 20/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 9.0039e-04
# Epoch 21/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.5987e-04
# Epoch 22/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.2888e-04
# Epoch 23/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.1358e-04
# Epoch 24/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.0980e-04
# Epoch 25/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.0925e-04
# Epoch 26/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.0171e-04
# Epoch 27/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 7.8358e-04
# Epoch 28/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 8.6863e-04
# Epoch 29/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 8.3597e-04
# Epoch 30/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 6.9106e-04
# Epoch 31/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 7.8750e-04
# Epoch 32/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 6.5127e-04
# Epoch 33/40
# 120/120 [==============================] - 0s 3ms/step - loss: 9.7722e-04 - val_loss: 5.9783e-04
# Epoch 34/40
# 120/120 [==============================] - 0s 3ms/step - loss: 9.8661e-04 - val_loss: 6.1522e-04
# Epoch 35/40
# 120/120 [==============================] - 0s 4ms/step - loss: 9.6611e-04 - val_loss: 5.8444e-04
# Epoch 36/40
# 120/120 [==============================] - 0s 4ms/step - loss: 9.8726e-04 - val_loss: 6.3979e-04
# Epoch 37/40
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 6.5814e-04
# Epoch 38/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 7.3007e-04
# Epoch 39/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 8.7761e-04
# Epoch 40/40
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 7.1995e-04
# [5.876400401347262, 6.0928772598624885, 5.012276631565984, 6.186828242452115, 8.356366433204347, 8.501348739052093, 6.234051345254551]
# '\nresultados = [valor for valor in forecast[0]]   \nobjeto = objeto.replace(" ",\'_\')\noutput = {objeto.lower():str(resultados)}\nfilename = f"previsao_DeepRNN_{objeto.lower()}_{regiao.lower()}_{forecast_horizon}_meses.json"\npasta_atual = os.getcwd()\nfull_url = Path(pasta_atual) / \'resultados\' / \'previsoes\' / filename\nos.makedirs(os.path.dirname(full_url), exist_ok=True)\nwith open(full_url,"w") as file:\n    json.dump(output,file,ensure_ascii=False)\nprint("Arquivo com resultados gerados")\n'

# %%
print("MAPE = ", round(mean_mape, 5))
print("RMSE = ", round(mean_rmse, 5))
# Out:
# MAPE =  6.5493
# RMSE =  0.02789

# %%
import matplotlib.pyplot as plt

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
fig = plt.figure(figsize=(16, 8))
plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
