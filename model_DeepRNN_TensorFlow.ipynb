# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import json
import configparser
from pathlib import Path
import os

from sklearn.metrics import mean_absolute_percentage_error as MAPE
from sklearn.metrics import mean_squared_error as MSE
def RMSE(y_real, y_predict):
    return np.sqrt(MSE(y_real, y_predict))

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN

configs = configparser.ConfigParser()
configs.read("configuracoes.conf",encoding='utf-8')
data_folder = Path(configs["DEFAULT"]["folder_path"])
path = data_folder / configs["DEFAULT"]["file"]
objeto = configs["DEFAULT"]["objeto"]
regiao = configs["DEFAULT"]["regiao"]

# %%
look_back = 12 #Quantidade de meses anteriores usado para prever
forecast_horizon = int(configs["DEFAULT"]["meses"]) #Quantidade de meses previstos

model_mape = []
model_rmse = []

for i in range(0,7):

    #Carrega os dados
    cesta = pd.read_excel(path)
    cesta.drop(['ano', 'salario', 'preco'], axis=1, inplace=True)

    #Cria sequencia de dados do tamanho (meses anterioes + meses a serem previstos)
    for n_step in range(1, look_back + forecast_horizon):
        cesta[f'razao t(h + {n_step})'] = cesta['razao'].shift(-n_step).values
    cesta.dropna(inplace=True)
    cesta.reset_index(drop=True, inplace=True)

    #Divide os dados em Treino e Teste
    X_train = cesta.iloc[:-67:, :look_back:].values
    y_train = cesta.iloc[:-67:, look_back::].values
    X_val = cesta.iloc[-67:-37:, :look_back:].values
    y_val = cesta.iloc[-67:-37:, look_back::].values
    y_val2 = cesta.iloc[-67:-37:, look_back::].values.tolist()

    #remodela os dados para formato (batchs, months, features)
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

    #Cria o modelo
    model=Sequential()
    model.add(SimpleRNN(64, input_shape=(look_back,1),return_sequences=True))
    model.add(SimpleRNN(64))
    model.add(Dense(forecast_horizon))
    model.compile(loss='mean_squared_error', optimizer='adam')

    #Treina e pever (forecast_horizon) quantidade de tempo
    history = model.fit(X_train, y_train, epochs= 20, batch_size=1, shuffle=False, validation_data=(X_val, y_val))
    forecast = model.predict(X_val)

    model_rmse.append(RMSE(y_val2, forecast))
    model_mape.append(MAPE(y_val2, forecast) * 100)

model_mape.sort()
model_rmse.sort()
model_mape.pop()
del model_mape[0]
model_rmse.pop()
del model_rmse[0]

mean_rmse = 0
mean_mape = 0

for rmse, mape in zip(model_rmse, model_mape):
    mean_rmse += rmse
    mean_mape += mape

mean_rmse = mean_rmse / 5
mean_mape = mean_mape / 5

"""
resultados = [valor for valor in forecast[0]]   
objeto = objeto.replace(" ",'_')
output = {objeto.lower():str(resultados)}
filename = f"previsao_DeepRNN_{objeto.lower()}_{regiao.lower()}_{forecast_horizon}_meses.json"
pasta_atual = os.getcwd()
full_url = Path(pasta_atual) / 'resultados' / 'previsoes' / filename
os.makedirs(os.path.dirname(full_url), exist_ok=True)
with open(full_url,"w") as file:
    json.dump(output,file,ensure_ascii=False)
print("Arquivo com resultados gerados")
"""
# Out:
# Epoch 1/20
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0065 - val_loss: 0.0045
# Epoch 2/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0044
# Epoch 3/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0047
# Epoch 4/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 5/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 6/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 7/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 8/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 9/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 10/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 11/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 12/20
# 120/120 [==============================] - ETA: 0s - loss: 0.001 - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 13/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 14/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 15/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 16/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 17/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 18/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 19/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 20/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 1/20
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0099 - val_loss: 0.0040
# Epoch 2/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0065
# Epoch 3/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0064
# Epoch 4/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0059
# Epoch 5/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0069
# Epoch 6/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0068
# Epoch 7/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 8/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 9/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 10/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 11/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 12/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 13/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 14/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 15/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 16/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 17/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 18/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 19/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 20/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 1/20
# 120/120 [==============================] - 2s 6ms/step - loss: 0.0127 - val_loss: 0.0036
# Epoch 2/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 3/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 4/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 5/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 6/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 7/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 8/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 9/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0044
# Epoch 10/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 11/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0058
# Epoch 12/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0054
# Epoch 13/20
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 14/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 15/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0046
# Epoch 16/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 17/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 18/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 19/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 20/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 1/20
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0079 - val_loss: 0.0055
# Epoch 2/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0075
# Epoch 3/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0060
# Epoch 4/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0065
# Epoch 5/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0067
# Epoch 6/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0057
# Epoch 7/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0053
# Epoch 8/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0049
# Epoch 9/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 10/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 11/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 12/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 13/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 14/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 15/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 16/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 17/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 18/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 19/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 20/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 1/20
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0125 - val_loss: 0.0038
# Epoch 2/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0056
# Epoch 3/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0049
# Epoch 4/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0049
# Epoch 5/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 6/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 7/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0036
# Epoch 8/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 9/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 10/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 11/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 12/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0035
# Epoch 13/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 14/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 15/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 16/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 17/20
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 18/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 19/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 20/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0019
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001EE41C688B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/20
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0120 - val_loss: 0.0029
# Epoch 2/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0041
# Epoch 3/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0048
# Epoch 4/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0049
# Epoch 5/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 6/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 7/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 8/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 9/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 10/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 11/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 12/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 13/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 14/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 15/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 16/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 17/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 18/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 19/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 20/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0028
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001EE41F16670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/20
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0065 - val_loss: 0.0031
# Epoch 2/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 3/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 4/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 5/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 6/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 7/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 8/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 9/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 10/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 11/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 12/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 13/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 14/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 15/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 16/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 17/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 18/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 19/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 20/20
# 120/120 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0023
# '\nresultados = [valor for valor in forecast[0]]   \nobjeto = objeto.replace(" ",\'_\')\noutput = {objeto.lower():str(resultados)}\nfilename = f"previsao_DeepRNN_{objeto.lower()}_{regiao.lower()}_{forecast_horizon}_meses.json"\npasta_atual = os.getcwd()\nfull_url = Path(pasta_atual) / \'resultados\' / \'previsoes\' / filename\nos.makedirs(os.path.dirname(full_url), exist_ok=True)\nwith open(full_url,"w") as file:\n    json.dump(output,file,ensure_ascii=False)\nprint("Arquivo com resultados gerados")\n'

# %%
print("MAPE = ", round(mean_mape, 5))
print("RMSE = ", round(mean_rmse, 5))
# Out:
# MAPE =  10.30344
# RMSE =  0.04569

# %%
import matplotlib.pyplot as plt

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
fig = plt.figure(figsize=(16, 8))
plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
